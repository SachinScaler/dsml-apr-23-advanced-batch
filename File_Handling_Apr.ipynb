# %% [markdown]
# ### File Access Modes
#
# >Access modes govern the type of operations possible in the opened file. It refers to how the file will be used once its opened. These modes also define the location of the File Handle in the file. File handle is like a cursor, which defines from where the data has to be read or written in the file. There are 6 access modes in python.
#
# - **Read Only (‘r’)** :
#     - Open text file for reading.
#     - The handle is positioned at the beginning of the file.
#     - If the file does not exists, raises I/O error.
#     - This is also the default mode in which file is opened.
#
#
# - **Read and Write (‘r+’)** :
#     - Open the file for reading and writing.
#     - The handle is positioned at the beginning of the file.
#     -  Raises I/O error if the file does not exists.
#
#
# - **Write Only (‘w’)** :
#     - Open the file for writing.
#     - For existing file, the data is truncated and over-written.
#     - The handle is positioned at the beginning of the file.
#
#     - Creates the file if the file does not exists.
#
#
# - **Write and Read (‘w+’)** :
#     - Open the file for reading and writing.
#     - For existing file, data is truncated and over-written.
#     - The handle is positioned at the beginning of the file.
#     - Creates the file if the file does not exists.
#
#
# - **Append Only (‘a’)** :
#     - Open the file for writing.
#     - The file is created if it does not exist.
#     - The handle is positioned at the end of the file.
#     - The data being written will be inserted at the end, after the existing data.
#
#
# - **Append and Read (‘a+’)** :
#     - Open the file for reading and writing.
#     - The file is created if it does not exist.
#     - The handle is positioned at the end of the file.
#     - The data being written will be inserted at the end, after the existing data.
#
# - **Read Binary ('rb')**
#     - read files in binary mode
#     - used for reading multi-media files mostly such as  image files like JPEGs or GIFs, audio files like MP3s or binary document formats like Word or PDF
# - **Write Binary ('wb')**
#     - Opens a file only for writing in binary format

# %%
import os

os.listdir()
# Out:
# ['.config', 'myfile.txt', '.ipynb_checkpoints', 'sample_data']

# %% [markdown]
# - **Read Only (‘r’)** :
#     - Open text file for reading.
#     - The handle is positioned at the beginning of the file.
#     - If the file does not exists, raises FileNotFound error.
#     - This is also the default mode in which file is opened.

# %%
f = open('myfile.txt','r')
# read content
f.read()
# Out:
# 'Hello'

# %%
f = open('thisfile.txt','r')
# read content
f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2574fe4b2a2d> in <cell line: 1>()
# ----> 1 f = open('thisfile.txt','r')
#       2 # read content
#       3 f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'thisfile.txt'

# %%
f = open('myfile.txt','r')
# read content
f.read()
# Out:
# 'Hello'

# %%
f.write("Hello2")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-7-47c6d1a5e142> in <cell line: 1>()
# ----> 1 f.write("Hello2")
#
# UnsupportedOperation: not writable

# %% [markdown]
# - **Read and Write (‘r+’)** :
#     - Open the file for reading and writing.
#     - The handle is positioned at the beginning of the file.
#     -  Raises I/O error if the file does not exists.

# %%
f = open('myfile.txt','r+')
# read content
f.read()
# Out:
# 'Hello'

# %%
f.write("World")
# Out:
# 5

# %%
f.close()

# %%
try:
    f = open('myfile.txt','r+')
except:
    pass
finally:
    f.close()
print(f.closed) # check close status
# Out:
# True

# %%
# context manager: Automatically closes the files and release resources after exiting with block
with open('myfile.txt','r+') as f1:
    f1.read()

print(f1.closed)
# Out:
# True

# %%
# context manager: Automatically closes the files and release resources after exiting with block
with open('myfile.txt','r+') as f1:
    str1 = f1.read()

print(f1.closed)
# Out:
# True

# %%
f1.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-5c2a67765a29> in <cell line: 1>()
# ----> 1 f1.read()
#
# ValueError: I/O operation on closed file.

# %%
str1
# Out:
# 'HelloWorld'

# %%
## cursor:is at the begining of file

with open('myfile.txt','r+') as f1:
    f1.write("ABC")

# HelloWorld
# HelloWorldABC
# ABC
# ABCloWorld

# %%
with open('myfile.txt','r+') as f1:
    f1.read()
    f1.write("ABC")

# %% [markdown]
# #### seek() to shift handle/position
# #### tell() to find the current posoition

# %%
with open('myfile.txt','r+') as f1:
    f1.seek(5)
    print(f1.tell())
    f1.write("Seeking to 5")
    print(f1.tell())
# Out:
# 5
# 17

# %%
with open('myfile22.txt','r+') as f1:
    f1.seek(5)
    print(f1.tell())
    f1.write("Seeking to 5")
    print(f1.tell())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-1bbce1983721> in <cell line: 1>()
# ----> 1 with open('myfile22.txt','r+') as f1:
#       2     f1.seek(5)
#       3     print(f1.tell())
#       4     f1.write("Seeking to 5")
#       5     print(f1.tell())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile22.txt'

# %% [markdown]
# - **Write Only (‘w’)** :
#     - Open the file for writing.
#     - For existing file, the data is truncated and over-written.
#     - The handle is positioned at the beginning of the file.
#
#     - Creates the file if the file does not exists.

# %%
with open('myfile22.txt','w') as f1:
    f1.write("Writing something")

# %%
with open('myfile.txt','w') as f1:
    f1.write("Writing something")

# %%
with open('myfile.txt','w') as f1:
    f1.write("A")

# %%
with open('myfile.txt','w') as f1:
    f1.read()
    f1.write("A")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-30-8fd5a2637bd0> in <cell line: 1>()
#       1 with open('myfile.txt','w') as f1:
# ----> 2     f1.read()
#       3     f1.write("A")
#       4
#       5
#
# UnsupportedOperation: not readable

# %% [markdown]
# - **Write and Read (‘w+’)** :
#     - Open the file for reading and writing.
#     - For existing file, data is truncated and over-written.
#     - The handle is positioned at the beginning of the file.
#     - Creates the file if the file does not exists.
#
#
# - **Append Only (‘a’)** :
#     - Open the file for writing.
#     - The file is created if it does not exist.
#     - The handle is positioned at the end of the file.
#     - The data being written will be inserted at the end, after the existing data.
#
#
# - **Append and Read (‘a+’)** :
#     - Open the file for reading and writing.
#     - The file is created if it does not exist.
#     - The handle is positioned at the end of the file.
#     - The data being written will be inserted at the end, after the existing data.
#
# - **Read Binary ('rb')**
#     - read files in binary mode
#     - used for reading multi-media files mostly such as  image files like JPEGs or GIFs, audio files like MP3s or binary document formats like Word or PDF
# - **Write Binary ('wb')**
#     - Opens a file only for writing in binary format

# %%
with open('myfile.txt','w+') as f1:
    print(f1.read())
    f1.seek(10)
    f1.write("A")
    print(f1.read())

# %%
with open('myfile2.txt','w') as f1:
    f1.seek(10)
    f1.write("A")

# %%
with open('myfile.txt','w') as f1:
    f1.write("A"*100)

# %%
with open('myfile.txt','w') as f1:
    f1.write("A\nA\n")

# %%
print("A\nA\nA")
# Out:
# A
# A
# A

# %%
with open('myfile.txt','w') as f1:
    f1.writelines(["Line1" , "Line2", "Line3"])

# %%
with open('myfile.txt','w') as f1:
    list1 = ["Line1" , "Line2", "Line3"]
    str1 = "\n".join(list1)
    f1.write(str1)

# %%
with open('myfile.txt','w+') as f1:
    list1 = ["Line1" , "Line2", "Line3"]
    str1 = "\n".join(list1)
    f1.write(str1)
    f1.seek(5) # reset position to 0
    print(f1.read())
# Out:
# Line2
# Line3

# %%
with open('myfile.txt','r') as f1:
    print(f1.read(5)) # reads everything
# Out:
# Line1

# %%
with open('myfile.txt','r') as f1:
    print(f1.readline()) # read one line at a time \n
# Out:
# Line1

# %%
with open('myfile.txt','r') as f1:
    print(f1.readline()) # read one line at a time \n
    print(f1.readline()) # read one line at a time \n
# Out:
# Line1
#
# Line2

# %%
with open('myfile.txt','r') as f1:
    print(f1.readlines()) # reads all lines to a list
# Out:
# ['Line1\n', 'Line2\n', 'Line3']

# %%
with open('myfile.txt','r') as f1:
    print(f1.read().split("\n"))
# Out:
# ['Line1', 'Line2', 'Line3']

# %% [markdown]
# - **Append Only (‘a’)** :
#     - Open the file for writing.
#     - The file is created if it does not exist.
#     - The handle is positioned at the end of the file.
#     - The data being written will be inserted at the end, after the existing data.

# %%
with open('filea.txt','a') as f1:
    f1.write("Hello")

# %%
with open('filea.txt','a') as f1:
    f1.write("Hello")

# %%
with open('filea.txt','a') as f1:
    f1.seek(0)
    f1.write("World")
    print(f1.read())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-63-2f8bc29bb252> in <cell line: 1>()
#       2     f1.seek(0)
#       3     f1.write("World")
# ----> 4     print(f1.read())
#
# UnsupportedOperation: not readable

# %% [markdown]
# - **Append and Read (‘a+’)** :
#     - Open the file for reading and writing.
#     - The file is created if it does not exist.
#     - The handle is positioned at the end of the file.
#     - The data being written will be inserted at the end, after the existing data.

# %%
with open('filea.txt','a+') as f1:
    f1.write("World")
    f1.seek(0)
    print(f1.read())
# Out:
# HELLOWorldWorld

# %% [markdown]
# #### 'rb' to handle multimedia

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'myfile.txt',
#  '.ipynb_checkpoints',
#  'myfile22.txt',
#  '1img.jpeg',
#  'filea.txt',
#  'myfile2.txt',
#  'sample_data']

# %%
with open("1img.jpeg", 'rb') as f:
    print(f.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x00\xff\xe1\x00\x97Exif\x00\x00II*\x00\x08\x00\x00\x00\x01\x00\x0e\x01\x02\x00u\x00\x00\x00\x1a\x00\x00\x00\x00\x00\x00\x00Wild grass in the mountains at sunset. Macro image, shallow depth of field. Vintage filter. Summer nature background.\xff\xe1\x05\x9bhttp://ns.adobe.com/xap/1.0/\x00<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\n<x:xmpmeta xmlns:x="adobe:ns:meta/">\n\t<rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">\n\t\t<rdf:Description rdf:about="" xmlns:photoshop="http://ns.adobe.com/photoshop/1.0/" xmlns:Iptc4xmpCore="http://iptc.org/std/Iptc4xmpCore/1.0/xmlns/"   xmlns:GettyImagesGIFT="http://xmp.gettyimages.com/gift/1.0/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:plus="http://ns.useplus.org/ldf/xmp/1.0/"  xmlns:iptcExt="http://iptc.org/std/Iptc4xmpExt/2008-02-29/" xmlns:xmpRights="http://ns.adobe.com/xap/1.0/rights/" photoshop:Credit="Getty Images/iStockphoto" GettyImagesGIFT:AssetID="1322277517" xmpRights:WebStatement="https://www.istockphoto.com/legal/license-agreement?utm_medium=organic&amp;utm_source=google&amp;utm_campaign=iptcurl" >\n<dc:creator><rdf:Seq><rdf:li>Olga_Gavrilova</rdf:li></rdf:Seq></dc:creator><dc:description><rdf:Alt><rdf:li xml:lang="x-default">Wild grass in the mountains at sunset. Macro image, shallow depth of field. Vintage filter. Summer nature background.</rdf:li></rdf:Alt></dc:description>\n<plus:Licensor><rdf:Seq><rdf:li rdf:parseType=\'Resource\'><plus:LicensorURL>https://www.istockphoto.com/photo/license-gm1322277517-?utm_medium=organic&amp;utm_source=google&amp;utm_campaign=iptcurl</plus:LicensorURL></rdf:li></rdf:Seq></plus:Licensor>\n\t\t</rdf:Description>\n\t</rdf:RDF>\n</x:xmpmeta>\n<?xpacket end="w"?>\n\xff\xed\x00\xc6Photoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\xaa\x1c\x02P\x00\x0eOlga_Gavrilova\x1c\x02x\x00uWild grass in the mountains at sunset. Macro image, shallow depth of field. Vintage filter. Summer nature background.\x1c\x02n\x00\x18Getty Images/iStockphoto\xff\xdb\x00C\x00\n\x07\x07\x08\x07\x06\n\x08\x08\x08\x0b\n\n\x0b\x0e\x18\x10\x0e\r\r\x0e\x1d\x15\x16\x11\x18#\x1f%$"\x1f"!&+7/&)4)!"0A149;>>>%.DIC<H7=>;\xff\xdb\x00C\x01\n\x0b\x0b\x0e\r\x0e\x1c\x10\x10\x1c;("(;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;\xff\xc2\x00\x11\x08\x01\x98\x02d.\x08j\x00\xc6\xa41\xa80\x86\xa8\x84\x91\x96\xb5+\x00\x08j\x00\x0e<\xfe\x98\xed\xe7\xbd\x15\xc00\x18\xc0p\xc0c\x02D\xb4\x94\x00\x00 \x10\x08\x04\x14\x80@ \x15\x08\x84*BEI\x11\x1b\xc00Pp\x0cj\x0e\x05`(\x8a@i\x14\xac P`\x10\ry5\x9e\xac\xda\x95\x80\xc6\x03\x80c\x18\x0c\x04\x05\x0e\xc0\x05\x00*\x01\x08\x04\x02\x01P \x10R\x12!R\x10\xacI\x9e\xf0\xc1\\\x03\x05c\x81X\x0c!\x11He\xcbP\xd4\x00\x08`\n\x1cvv\xe6\xb1\x80\xe0V4`1\x8c\x10\x00*\x84\x00\x15\x04 T\x02\x10\x80\x04*\x00B\x01RD*BEYo\x9bW\x00\xc1X\xe0V\x03\x80j\x88D5\xb8\xa5\x06\x00\x10\rAG\x16\xf3\xdf\x8d1\x80\xa5\x83B\xd1\x8c\x06\x8c)\xa0\xa20\xa0 \x10\tH@\xa8B\x01\x00\x82\x90\x08\x04*BD*F]99A\x82\xb8`\xaca\x02\xb0\x02\x00qK@\x01\x0c\x01XB9u;3X\xe0%r7-\x18\xc1\x1d4\x06\x01`\x00\x00\x01*\x05P\x81P\x80B\x01\x05 \x10\x08B\xa4\x88U\x8fNn\x18+\x865\x06\x10\xd4\x01\x84J\xa1\x94T\x00\x03\x14\xac`\x065\xbc8`%\x93Tc\x1a\x14\xd1\x85\x80\x00\x00\x00\x00\x04\xa8\x15B\x05B\x01\x08\x00T\x08@!\n\xc4#\x0e\x9c\xe8jC\x1a\x83\x81A\x8c\x02\x02T\x02\x8a\x86\n\x04rk=9\xd5\x8c\x05\x140V\x89YH\xc6\x854a`\x00\x00\x00\x00\x00\x01*\x05P\x81P\x80@ \x10R\x01\x08B\xb1\x1c\xdd9\xda\xb8cPp\xcc\xca)\\0\x05\x90\x02\xa2\x80R\x85\x1c;\xcfV.\xaa\xc0%h\x02\xb4\x15\xa5\r\x01\xd0\x8c,` \x00\x00\x00\x00\x00\x95\tH@\xa8@ \x10\x00\xa9\x00\x84!Y\xc7\xd7\x96\xb9\xd5\r\\\x03\x1a\xe1d\xa7Fu@5\x04(c(K0\x16g`\xbbA\x0c\x ...

# %%
# copy paste functionality in OS
with open("1img.jpeg", 'rb') as f:
    binary_data = (f.read())

with open("1img_copy.jpeg", 'wb') as f:
    print(f.write(binary_data))
# Out:
# 23957

# %%
with open("filea.txt", 'rb') as f:
    data = (f.read())
    print(data)
    print(type(data))
# Out:
# b'HELLOWorldWorld'
# <class 'bytes'>

# %%
with open("/content/sample_data/README.md", 'r') as f:
    data = (f.read())
    print(data)
    print(type(data))
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).
#
# <class 'str'>

# %%
with open("sample_data/README.md", 'r') as f:
    data = (f.read())
    print(data)
    print(type(data))
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).
#
# <class 'str'>

# %%
### [2d] # 3d [[[]]]

# %%
os.getcwd()
# Out:
# '/content'

# %%
# %%writefile mycustommodule.txt
# with open("sample_data/README.md", 'r') as f:
#     data = (f.read())
#     print(data)
#     print(type(data))
# Out:
# Writing mycustommodule.txt

# %%
class A: # inheriting form object __methodName__
    pass

# %%
# %%timeit
for i in range(10):
    pass
# Out:
# 178 ns ± 28.7 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %%timeit
range(1,10)
# Out:
# 93.3 ns ± 26.3 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
